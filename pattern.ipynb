# %%
n=int(input())
for i in range(1,n):
    for j in range(n):
        print(i,end="")
    print()
# Out:
# 5
# 11111
# 22222
# 33333
# 44444

# %%
n=int(input())
for i in range(n):
    for j in range(1,5):
        print(j,end="")
    print()
# Out:
# 4
# 1234
# 1234
# 1234
# 1234

# %%
n=int(input())
for i in range(6):
    for j in range(n-i-1):
         print(" ",end="")
    for j in range(i+1):
         print(j+1,end="")
    print()
# Out:
# 6
#      1
#     12
#    123
#   1234
#  12345
# 123456

# %%
n=int(input())
i=1
while i<=n
      j=1
      while j<=n:
            if j==1:
                print(1,end=" ")
            else:
                print(0," ")
            j=j+1
        print()
        i=1+1
# Out:
#   File <tokenize>:11
#     print()
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def add(a,b):
print(a+b)
add(8,5)
print()
# Out:
#   Input In [14]
#     def add(a,b)
#                 ^
# SyntaxError: invalid syntax

# %%
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
                
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
            
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        zx
        \
# Out:
#   Input In [17]
#     def add(55,64,75,80,65):
#             ^
# SyntaxError: invalid syntax

# %%
def cal_average(num):
         sum_num =0 
        for t in num:
           sum_num = sum_num+t
    avg = sum_num / len(num)
    return avg
 print("the average is" , cal_average([55,64,75,80,65]))
# Out:
#   File <tokenize>:5
#     avg = sum_num / len(num)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def average (a,b,c,d,e)
    average=(a+b+c+d+e)/5
